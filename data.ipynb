# %% [markdown]
# Notebook for testing the VAE, loading the dataseet, and creating the latent space dataset

# %%
import pandas as pd
import torch
import numpy as np
from tqdm import tqdm

import json
import lightning.pytorch as pl
import torch
from torch.nn.utils.rnn import pad_sequence
import selfies as sf
import time

from molformers.models.BaseTrainer import VAEModule
from molformers.models.BaseVAESwiGLURope import BaseVAE
from typing import List, Union, Optional

torch.set_float32_matmul_precision("high")

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using: {device}")
# Out:
# Using: cuda

# %%
from load_and_sample import *

# %%
# test if the VAE is working
example_usage()
# Out:
# loading model from ./saved_models/epoch=447-step=139328.ckpt
# Enc params: 1,994,592
# Dec params: 277,346
# c:\Users\2023r\Documents\GuidedDiffusionProject\load_and_sample.py:39: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path_to_vae_statedict, map_location=device)["state_dict"]
# Latent shape: torch.Size([1, 128]), Loss: 0.0002240684552816674
# Reconstructed: ['[C][C][C][O]']
# Batch latent shape: torch.Size([5, 128])
# Reconstructed batch: ['[C][C][C][C][=Branch1][C][=O][N][N][C][=Branch1][C][=O][N][C][=C][C][=C][C][=C][Ring1][=Branch1]', '[C][C][=Branch1][C][=O][N][C][C][C][C][Branch1][C][C][C][Branch2][Ring2][#Branch2][C][C][C][Branch1][C][C][C][Ring1][Branch2][C][=Branch1][C][=O][C][=C][C][C][Branch1][C][C][C][Branch1][C][C][C][C][C][Ring1][Branch2][Branch1][C][C][C][C][C][Ring1][=N][Ring2][Ring1][Ring1][C][C][Ring2][Ring1][=N][Branch1][C][C][C][=Branch1][C][=O][O]', '[C][C][=Branch1][C][=O][N][C][Branch1][C][C][C][C][=C][C][=C][Branch2][Ring1][Branch2][C][#C][C][=C][C][=N][C][Branch1][N][N][C][C][C][C][Branch1][C][F][C][Ring1][#Branch1][=N][Ring1][=N][C][=C][Ring2][Ring1][Branch1]', '[C][C][=C][C][=C][C][Branch2][Ring1][P][C][C][N][C][=Branch1][C][=O][C][C][C][C][=Branch1][C][=O][N][Branch1][=N][C][C][=C][C][=C][Branch1][C][Cl][C][=C][Ring1][#Branch1][C][Ring1][#C][=N][Ring2][Ring1][#Branch2]', '[C][C][C][=C][N][Branch1][=Branch1][N][Branch1][C][C][C][C][=C][Ring1][=Branch2][C][=Branch1][C][=O][C][=C][N][=C][C][=C][Ring1][=Branch1][C][Ring1][O][=O]']
# Reconstruction accuracy: 100.00%

# %%
# Convert the smiles dataset into a selfies one

def smiles_to_selfies(smiles_list : List[str]):
    """Converts SMILES (guacamol dataset format) to SELFIES (vae format)"""

    selfies_list = []

    for i, smiles in enumerate(smiles_list):
        try:
            selfies_string = sf.encoder(smiles.strip())
            selfies_list.append(selfies_string)
        except Exception as e:
            print(f"Error: {e}\n")
    
    return selfies_list

def selfies_to_smiles(selfies_list : List[str]):
    smiles_list = []

    for i, selfies in enumerate(selfies_list):
        try:
            smiles_string = sf.decoder(selfies.strip())
            smiles_list.append(smiles_string)
        except Exception as e:
            print(f"Error: {e}\n")
    
    return smiles_list


def smiles_to_selfies_file(input_smiles_file : str, output_selfies_file : str) -> List[str]:
    """Takes a smiles file and outputs a list of selfies, saves results"""

    with open(input_smiles_file, 'r') as f:
        smiles_list = [line.strip() for line in f if line.strip()]

    print(f"Converting {len(smiles_list)} strings to SMILES format...")

    selfies_list = smiles_to_selfies(smiles_list)
    df = pd.DataFrame({'SELFIES': selfies_list})

    if output_selfies_file:
        df.to_csv(output_selfies_file, index=False)

    return selfies_list

# %%
input_file = "C:/Users/2023r/Documents/GuidedDiffusionProject/guacamol_v1_train.smiles"

# %%
# smiles_to_selfies_file(input_smiles_file=input_file, output_selfies_file="output_selfies.csv")
# Out:
# Converting 1273104 strings to SMILES format...
# Error: input violates the currently-set semantic constraints
# 	SMILES: CC(=O)O[IH2]1NC(=O)c2ccccc21
# 	Errors:
# 	[[IH2] with 3 bond(s) - a max. of -1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: CC(=O)OI1(OC(C)=O)(OC(C)=O)OC(=O)c2ccccc21
# 	Errors:
# 	[I with 5 bond(s) - a max. of 1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: O=C1OI(=O)(O)c2ccccc21
# 	Errors:
# 	[I with 5 bond(s) - a max. of 1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: CCC(=O)N[IH2]1OC(=O)c2ccccc21
# 	Errors:
# 	[[IH2] with 3 bond(s) - a max. of -1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: [N-]=[N+]=N[IH2]1OC(=O)c2ccccc21
# 	Errors:
# 	[[IH2] with 3 bond(s) - a max. of -1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: O=C(N[IH2]1OC(=O)c2ccccc21)c1ccc(Cl)cc1
# 	Errors:
# 	[[IH2] with 3 bond(s) - a max. of -1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: O=I(=O)c1ccc(I(=O)=O)cc1
# 	Errors:
# 	[I with 5 bond(s) - a max. of 1 bond(s) was specified]
# 	[I with 5 bond(s) - a max. of 1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: O=C1O[IH2](O)c2ccccc21
# 	Errors:
# 	[[IH2] with 3 bond(s) - a max. of -1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: O=P1(O)Oc2ccccc2I(=O)(O)O1
# 	Errors:
# 	[I with 5 bond(s) - a max. of 1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: O=C(O)c1ccc(I(=O)=O)cc1
# 	Errors:
# 	[I with 5 bond(s) - a max. of 1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: O=I(=O)c1c[nH]cn1
# 	Errors:
# 	[I with 5 bond(s) - a max. of 1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: O=S(=O)(O[IH2](O)CC(F)(F)F)C(F)(F)F
# 	Errors:
# 	[[IH2] with 3 bond(s) - a max. of -1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: O=S(=O)(O[IH2](O[IH2](OS(=O)(=O)C(F)(F)F)c1ccccc1)c1ccccc1)C(F)(F)F
# 	Errors:
# 	[[IH2] with 3 bond(s) - a max. of -1 bond(s) was specified]
# 	[[IH2] with 3 bond(s) - a max. of -1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: O=[N+]([O-])c1cccc(I(=O)=O)c1
# 	Errors:
# 	[I with 5 bond(s) - a max. of 1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: CC(=O)O[IH2](OC(C)=O)c1ccccc1
# 	Errors:
# 	[[IH2] with 3 bond(s) - a max. of -1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: N#C[IH2]1OC(C(F)(F)F)(C(F)(F)F)c2ccccc21
# 	Errors:
# 	[[IH2] with 3 bond(s) - a max. of -1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: c1ccc2c(c1)Ic1ccccc1-2
# 	Errors:
# 	[I with 2 bond(s) - a max. of 1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: O=I(=O)c1ccccc1
# 	Errors:
# 	[I with 5 bond(s) - a max. of 1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: CC(C)(C)C#C[IH2]1OC(=O)c2ccccc21
# 	Errors:
# 	[[IH2] with 3 bond(s) - a max. of -1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: O=C1N[IH2](C#Cc2ccccc2)c2ccccc21
# 	Errors:
# 	[[IH2] with 3 bond(s) - a max. of -1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: Cc1ccc(I(=O)=O)cc1
# 	Errors:
# 	[I with 5 bond(s) - a max. of 1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: O=C(O)c1cccc(I(=O)=O)c1
# 	Errors:
# 	[I with 5 bond(s) - a max. of 1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: N#C[IH2]1OC(=O)c2ccccc21
# 	Errors:
# 	[[IH2] with 3 bond(s) - a max. of -1 bond(s) was specified]
#
#
# Error: input violates the currently-set semantic constraints
# 	SMILES: [N-]=[N+]=N[IH2]1OC(C(F)(F)F)(C(F)(F)F)c2ccccc21
# 	Errors:
# 	[[IH2] with 3 bond(s) - a max. of -1 bond(s) was specified]
#  '[C][C][=C][C][=C][C][=C][Ring1][=Branch1][O][C][C][=C][C][Branch1][=C][C][#C][C][=C][C][=C][Branch1][C][Br][C][=C][Ring1][#Branch1][O][C][Ring1][#C][C][O]',
#  '[C][C][=C][C][Branch1][Ring1][C][O][=C][C][=C][Ring1][Branch2][C][=C][C][=C][Branch2][Ring2][C][N][Branch1][#Branch2][C][C][Branch1][C][F][Branch1][C][F][F][S][=Branch1][C][=O][=Branch1][C][=O][C][=C][C][=C][C][=C][Ring1][=Branch1][C][=C][N][Ring1][Branch1][C][C][=C][Ring2][Ring1][=Branch2]',
#  '[O][C][C][C][C][C][Branch2][Ring1][=Branch1][N][C][=N][C][=C][Branch1][#Branch1][N][C][C][C][Ring1][Ring1][C][=C][N][=C][Ring1][#Branch2][Ring1][=N][O][Ring2][Ring1][C]',
#  '[C][N][Branch1][C][C][C][C][C][C][O][C][=Branch1][C][=O][N][C][=C][C][=C][C][Branch2][Ring1][=Branch1][C][N][N][=C][Branch1][#Branch2][N][C][=C][C][=C][C][=C][Ring1][=Branch1][C][=C][C][Ring1][=N][=O][=C][Ring2][Ring1][Branch1]',
#  ...]

# %%
# Now we want to convert all of the output_selfies.csv to their 128 dim latent codes

vae = load_vae_selfies("./saved_models/epoch=447-step=139328.ckpt")
selfies_df = pd.read_csv("output_selfies.csv")['SELFIES']
# Out:
# loading model from ./saved_models/epoch=447-step=139328.ckpt
# Enc params: 1,994,592
# Dec params: 277,346

# %%
selfies_latents = []
failed_selfies = []

for i, selfie in enumerate(tqdm(selfies_df, desc="Processing SELFIES")):
    try:
        latent = selfies_to_latent([selfie], vae=vae)
        selfies_latents.append(latent[0])
    except Exception as e:
        tqdm.write(f"Failed SELFIES at index {i}: {selfie[:50]}...")  # Truncate for readability
        tqdm.write(f"Error: {e}")
        failed_selfies.append((i, selfie, str(e)))

df = pd.DataFrame(selfies_latents)
df.to_csv("selfies_latents.csv", index=False)

if failed_selfies:
    print(f"\nTotal failed: {len(failed_selfies)}")
    failed_df = pd.DataFrame(failed_selfies, columns=['index', 'selfies', 'error'])
    failed_df.to_csv("failed_selfies.csv", index=False)
# Out:
# Processing SELFIES:  11%|█         | 141304/1273079 [22:07<4:19:28, 72.70it/s]
# Failed SELFIES at index 141295: [F][P-1][Branch1][C][F][Branch1][C][F][Branch1][C]...
# Error: '[P-1]'
# Processing SELFIES:  60%|█████▉    | 758786/1273079 [2:07:06<1:10:49, 121.01it/s]

# %%
import pandas as pd
import torch
import numpy as np
from tqdm import tqdm
import pickle

import lightning.pytorch as pl
import torch

from load_and_sample import *
import gzip

torch.set_float32_matmul_precision("high")

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using: {device}")

vae = load_vae_selfies("./saved_models/epoch=447-step=139328.ckpt")
vae.to(device).eval()

selfies_latents = []
failed_selfies = []

save_every = 50000 # save every 50k

with gzip.open('data/val_selfie.gz', 'rt', encoding='utf-8') as f:
    for i, line in enumerate(tqdm(f, desc='Processing Selfies strings...')):
        selfie = line.strip()

        # get latent code and add it
        try:
            latent = selfies_to_latent([selfie], vae=vae)
            selfies_latents.append(latent[0].cpu().numpy())

        # theres like two buggy ones
        except Exception as e:
            tqdm.write(f"Failed SELFIES at index {i}: {selfie[:50]}...")
            tqdm.write(f"Error: {e}")
            failed_selfies.append((i, selfie, str(e)))

         # save every 50k samples or so
        if (i + 1) % save_every == 0:
            np.save(f"latents_chunk.npy", np.array(selfies_latents, dtype=np.float32))
            
np.save(f"latents_final.npy", np.array(selfies_latents, dtype=np.float32))
# Out:
# c:\Users\2023r\Documents\GuidedDiffusionProject\load_and_sample.py:39: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path_to_vae_statedict, map_location=device)["state_dict"]
# Using: cuda
# loading model from ./saved_models/epoch=447-step=139328.ckpt
# Enc params: 1,994,592
# Dec params: 277,346
# Processing Selfies strings...: 644it [00:04, 156.66it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 32
#      30 # get latent code and add it
#      31 try:
# ---> 32     latent = selfies_to_latent([selfie], vae=vae)
#      33     selfies_latents.append(latent[0].cpu().numpy())
#      35 # theres like two buggy ones
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\load_and_sample.py:139, in selfies_to_latent(selfies, vae)
#     137     return selfies_to_latent_helper(selfies, vae)
#     138 elif isinstance(selfies, list):
# --> 139     return torch.cat([selfies_to_latent_helper(s, vae) for s in selfies], dim=0)
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\load_and_sample.py:139, in <listcomp>(.0)
#     137     return selfies_to_latent_helper(selfies, vae)
#     138 elif isinstance(selfies, list):
# --> 139     return torch.cat([selfies_to_latent_helper(s, vae) for s in selfies], dim=0)
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\load_and_sample.py:128, in selfies_to_latent_helper(selfie, vae)
#     126 with torch.no_grad():
#     127     tokens = vae.selfie_to_tokens(selfie).unsqueeze(0).to(device)
# --> 128     out = vae.model(tokens)
#     129     z = out["mu_ign"] + out["sigma_ign"] * torch.randn_like(out["sigma_ign"])
#     131 return z.reshape(-1, vae.model.n_acc * vae.model.d_bnk)
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\molformers\models\BaseVAESwiGLURope.py:112, in BaseVAE.forward(self, tokens)
#     109 mu, sigma = self.encode(tokens)
#     110 z = mu + torch.randn_like(sigma)*sigma
# --> 112 logits = self.decode(z, tokens)
#     114 # Autoregressive shift
#     115 logits = logits[:, :-1]
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\molformers\models\BaseVAESwiGLURope.py:103, in BaseVAE.decode(self, z, tokens)
#     101 tgt_mask = causal_mask(embed.shape[1], embed.device, embed.dtype)
#     102 # Sometimes we dont use a strictly causal mask
# --> 103 decoding = self.decoder(tgt=embed, mem=z, tgt_mask=tgt_mask)
#     104 logits = self.dec_tok_deproj(decoding)
#     106 return logits
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\.venv\Lib\site-packages\hnn_utils\nn\Transformer.py:74, in TransformerDecoder.forward(self, tgt, mem, tgt_mask, mem_mask, tgt_pad_mask, mem_pad_mask, tgt_is_causal, mem_is_causal)
#      71 output = tgt
#      73 for layer in self.layers:
# ---> 74     output = layer(
#      75         output,
#      76         mem,
#      77         tgt_mask,
#      78         mem_mask,
#      79         tgt_pad_mask,
#      80         mem_pad_mask,
#      81         tgt_is_causal,
#      82         mem_is_causal,
#      83     )
#      85 return output
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\.venv\Lib\site-packages\hnn_utils\nn\Transformer.py:214, in TransformerDecoderLayer.forward(self, tgt, mem, tgt_mask, mem_mask, tgt_pad_mask, mem_pad_mask, tgt_is_causal, mem_is_causal)
#     212     x = x + self.ff_block(self.norm3(x))
#     213 else:
# --> 214     x = self.norm1(x + self._sa_block(x, tgt_mask, tgt_pad_mask, is_causal=tgt_is_causal))  # fmt: skip
#     215     x = self.norm2(x + self._mha_block(x, mem, mem_mask, mem_pad_mask, mem_is_causal))  # fmt: skip
#     216     x = self.norm3(x + self.ff_block(x))
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\.venv\Lib\site-packages\hnn_utils\nn\Transformer.py:226, in TransformerDecoderLayer._sa_block(self, x, attn_mask, pad_mask, is_causal)
#     219 def _sa_block(
#     220     self,
#     221     x: Tensor,
#    (...)    224     is_causal: bool = False,
#     225 ) -> Tensor:
# --> 226     x = self.self_attn(x, attn_mask=attn_mask, pad_mask=pad_mask, is_causal=is_causal)  # fmt: skip
#     227     return self.dropout1(x)
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\.venv\Lib\site-packages\hnn_utils\nn\Transformer.py:343, in SelfAttention.forward(self, x, pad_mask, attn_mask, is_causal)
#     340     mask = mask + cm if mask is not None else cm
#     342 dropout = self.dropout if self.training else 0.0
# --> 343 attn = F.scaled_dot_product_attention(q, k, v, mask, dropout_p=dropout)
#     345 attn = rearrange(attn, "... h n d -> ... n (h d)")
#     346 return self.out_proj(attn)
#
# KeyboardInterrupt:

# %%
vae = load_vae_selfies("./saved_models/epoch=447-step=139328.ckpt")
vae.to(device)
vae.eval()
# Out:
# loading model from ./saved_models/epoch=447-step=139328.ckpt
# Enc params: 1,994,592
# Dec params: 277,346
# c:\Users\2023r\Documents\GuidedDiffusionProject\load_and_sample.py:39: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path_to_vae_statedict, map_location=device)["state_dict"]
# VAEModule(
#   (model): BaseVAE(
#     (encoder_token_embedding): Embedding(
#       (embedding): Embedding(98, 256, padding_idx=97)
#       (pos_enc): SinePosEnc(
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (decoder_token_embedding): Embedding(
#       (embedding): Embedding(98, 64, padding_idx=97)
#       (pos_enc): SinePosEnc(
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (enc_neck): Sequential(
#       (0): Linear(in_features=256, out_features=64, bias=True)
#       (1): GELU(approximate='none')
#       (2): Linear(in_features=64, out_features=32, bias=True)
#     )
#     (dec_neck): Sequential(
#       (0): Linear(in_features=16, out_features=256, bias=True)
#       (1): GELU(approximate='none')
#       (2): Linear(in_features=256, out_features=64, bias=True)
#     )
#     (dec_tok_deproj): Linear(in_features=64, out_features=98, bias=True)
#     (encoder): TransformerEncoder(
#       (layers): ModuleList(
#         (0-2): 3 x TransformerEncoderLayer(
#           (self_attn): SelfAttention(
#             (qkv_proj): Linear(in_features=256, out_features=768, bias=True)
#             (out_proj): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (ff_block): FFNSwiGLU(
#             (ff1): Linear(in_features=256, out_features=1024, bias=True)
#             (ff2): Linear(in_features=512, out_features=256, bias=True)
#           )
#           (norm1): LayerNorm(
#             (ln): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#           (norm2): LayerNorm(
#             (ln): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (decoder): TransformerDecoder(
#       (layers): ModuleList(
#         (0-2): 3 x TransformerDecoderLayer(
#           (self_attn): SelfAttention(
#             (qkv_proj): Linear(in_features=64, out_features=192, bias=True)
#             (out_proj): Linear(in_features=64, out_features=64, bias=True)
#           )
#           (cross_attn): CrossAttention(
#             (q_proj): Linear(in_features=64, out_features=64, bias=True)
#             (kv_proj): Linear(in_features=64, out_features=128, bias=True)
#             (out_proj): Linear(in_features=64, out_features=64, bias=True)
#           )
#           (ff_block): FFNSwiGLU(
#             (ff1): Linear(in_features=64, out_features=512, bias=True)
#             (ff2): Linear(in_features=256, out_features=64, bias=True)
#           )
#           (norm1): LayerNorm(
#             (ln): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#           (norm2): LayerNorm(
#             (ln): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#           (norm3): LayerNorm(
#             (ln): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           )
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (val_kld): KLCalc()
# )

# %%
vae = load_vae_selfies("./saved_models/epoch=447-step=139328.ckpt")
vae.to(device).eval()

selfies_latents = []
failed_selfies = []

save_every = 50000 # save every 50k

with gzip.open('data/val_selfie.gz', 'rt', encoding='utf-8') as f:
    for i, line in enumerate(tqdm(f, desc='Processing Selfies strings...')):
        selfie = line.strip()

        # get latent code and add it
        try:
            latent = selfies_to_latent([selfie], vae=vae)
            selfies_latents.append(latent[0].cpu().numpy())

        # theres like two buggy ones
        except Exception as e:
            tqdm.write(f"Failed SELFIES at index {i}: {selfie[:50]}...")
            tqdm.write(f"Error: {e}")
            failed_selfies.append((i, selfie, str(e)))

         # save every 50k samples or so
        if (i + 1) % save_every == 0:
            np.save(f"latents_chunk.npy", np.array(selfies_latents, dtype=np.float32))
            
np.save(f"latents_final.npy", np.array(selfies_latents, dtype=np.float32))
# Out:
# Processing Selfies strings...: 446it [00:02, 155.18it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 12
#      10 # get latent code and add it
#      11 try:
# ---> 12     latent = selfies_to_latent([selfie], vae=vae)
#      13     selfies_latents.append(latent[0].cpu().numpy())
#      15 # theres like two buggy ones
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\load_and_sample.py:139, in selfies_to_latent(selfies, vae)
#     137     return selfies_to_latent_helper(selfies, vae)
#     138 elif isinstance(selfies, list):
# --> 139     return torch.cat([selfies_to_latent_helper(s, vae) for s in selfies], dim=0)
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\load_and_sample.py:139, in <listcomp>(.0)
#     137     return selfies_to_latent_helper(selfies, vae)
#     138 elif isinstance(selfies, list):
# --> 139     return torch.cat([selfies_to_latent_helper(s, vae) for s in selfies], dim=0)
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\load_and_sample.py:128, in selfies_to_latent_helper(selfie, vae)
#     126 with torch.no_grad():
#     127     tokens = vae.selfie_to_tokens(selfie).unsqueeze(0).to(device)
# --> 128     out = vae.model(tokens)
#     129     z = out["mu_ign"] + out["sigma_ign"] * torch.randn_like(out["sigma_ign"])
#     131 return z.reshape(-1, vae.model.n_acc * vae.model.d_bnk)
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\molformers\models\BaseVAESwiGLURope.py:132, in BaseVAE.forward(self, tokens)
#     129 kldiv = kldiv.mean() + (kldiv.mean(dim=0) - kldiv.detach().mean()).abs().mean()
#     131 loss = recon_loss + kl_fac * kldiv
# --> 132 with torch.no_grad():
#     133     preds = logits.argmax(dim=-1)
#     134     mask = tokens != self.pad_tok
#
# File c:\Users\2023r\Documents\GuidedDiffusionProject\.venv\Lib\site-packages\torch\utils\_contextlib.py:154, in _NoParamDecoratorContextManager.__new__(cls, orig_func)
#     151 class _NoParamDecoratorContextManager(_DecoratorContextManager):
#     152     """Allow a context manager to be used as a decorator without parentheses."""
# --> 154     def __new__(cls, orig_func=None):
#     155         if orig_func is None:
#     156             return super().__new__(cls)
#
# KeyboardInterrupt:
